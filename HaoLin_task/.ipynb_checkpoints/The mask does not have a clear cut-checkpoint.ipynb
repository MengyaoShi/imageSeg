# %%
from PIL import Image
import os
import numpy as np
from paths import *

# %%
mask_path = data_path +"/train_masks/"

# %%
i = 2
file_path = mask_path + str(i)+".png"
mask = Image.open(file_path)

mask = mask.resize((128,128), Image.ANTIALIAS)
mask = np.copy(np.asarray(mask))
mask = mask.sum(axis = 2)

mask = mask /(255*3)
mask = mask.astype(np.float32)

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = np.random.normal(size = 1000)
plt.hist(mask.flatten(), normed=True, bins=60)
plt.ylabel('Probability');

# %%
mask = mask > 0.7

# %%
from matplotlib import pyplot as plt
plt.imshow(mask, cmap = 'gray', interpolation = 'bicubic')
plt.show()
